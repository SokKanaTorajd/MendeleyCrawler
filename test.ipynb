# %%
from selenium.webdriver import Firefox
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from time import sleep

import pandas as pd
import csv

# %%
'/html/body/div[2]/div/div[2]/div/div[1]/div[3]'
'/html/body/div[2]/div/div[2]/div/div[1]/div[2]'

# %%
title_xpath = "/html/body/div[2]/div/div[1]/div/div/div/div[1]/div/div/div[1]/h1"
authors_xpath = "//html/body/div[2]/div/div[1]/div/div/div/div[1]/div/div/div[1]/div[1]/div/ul/li"
publisher_xpath = "/html/body/div[2]/div/div[1]/div/div/div/div[1]/div/div/div[1]/div[2]/div/div"
docId_xpath = "/html/body/div[2]/div/div[1]/div/div/div/div[1]/div/div/div[1]/div[3]/a"
abstract_xpath = "/html/body/div[2]/div/div[2]/div/div[1]/div[1]/p/span"
keywords_xpath = "/html/body/div[2]/div/div[2]/div/div[1]/div[2]/ul/li"

# %%
def insert_detail(file, detail):
    with open(file, 'a+', newline='\n', encoding='utf-8') as f:
        csv_write = writer(f)
        csv_write.writerow(detail)
        print('detail inserted')
        f.close()

# %%
# Out:
# 0       https://www.mendeley.com/catalogue/189518ae-c7...
# 1       https://www.mendeley.com/catalogue/e3b6b38f-06...
# 2       https://www.mendeley.com/catalogue/f85f3983-fc...
# 3       https://www.mendeley.com/catalogue/c5045303-e1...
# 4       https://www.mendeley.com/catalogue/973c2f5a-03...
#                               ...
# 1894    https://www.mendeley.com/catalogue/95b402eb-be...
# 1895    https://www.mendeley.com/catalogue/5438be1d-31...
# 1896    https://www.mendeley.com/catalogue/a0d6580a-f8...
# 1897    https://www.mendeley.com/catalogue/2d3c8eb8-f3...
# 1898    https://www.mendeley.com/catalogue/0980df84-07...
# Name: url, Length: 1899, dtype: object

# %%
# import csv

# with open('./data/details.csv', 'r', encoding="cp1252") as f:
#     reader = csv.reader(f)
#     for row in reader:
#         print(row)

# %%
# url = "https://www.mendeley.com/catalogue/05663b77-764e-34d5-bc67-48b45631d458"

# title_xpath = "/html/body/div[2]/div/div[1]/div/div/div/div[1]/div/div/div[1]/h1"
# authors_xpath = "//html/body/div[2]/div/div[1]/div/div/div/div[1]/div/div/div[1]/div[1]/div/ul/li"
# publisher_xpath = "/html/body/div[2]/div/div[1]/div/div/div/div[1]/div/div/div[1]/div[2]/div/div"
# docId_xpath = "/html/body/div[2]/div/div[1]/div/div/div/div[1]/div/div/div[1]/div[3]/a"
# abstract_xpath = "/html/body/div[2]/div/div[2]/div/div[1]/div[1]/p/span"
# keywords_xpath = "/html/body/div[2]/div/div[2]/div/div[1]/div[2]/ul/li"

# driver = Firefox(executable_path='./driver/geckodriver.exe')
# driver.get(url)

# try:
#     cookies = driver.find_element_by_id("onetrust-accept-btn-handler")
#     cookies.click()
#     print('cookies are accepted')
#     sleep(3)
# except NoSuchElementException:
#     print('cookies button unavailable')
#     pass

# title = driver.find_element_by_xpath(title_xpath).text
# print('title acquired')

# publisher = driver.find_element_by_xpath(publisher_xpath).text
# print('publisher acquired')

# try:
#     doc_id = driver.find_element_by_xpath(docId_xpath).text
#     print('doc_id acquired')
# except NoSuchElementException:
#     doc_id = ''
#     print('doc_id unavailable')
#     pass

# abstract = driver.find_element_by_xpath(abstract_xpath).text
# print('abstract acquired')

# authors = driver.find_elements_by_xpath(authors_xpath)
# auths = []
# for i in range(len(authors)):
#     aux = "//html/body/div[2]/div/div[1]/div/div/div/div[1]/div/div/div[1]/div[1]/div/ul/li[{}]".format(str(i+1))
#     authr = driver.find_element_by_xpath(aux).text
#     auths.append(authr)
# print('auhors acquired')

# keywords = driver.find_elements_by_xpath(keywords_xpath)
# keys = []
# for i in range(len(keywords)):
#     keyx = "/html/body/div[2]/div/div[2]/div/div[1]/div[2]/ul/li[{}]".format(str(i+1))
#     key_word = driver.find_element_by_xpath(keyx).text
#     keys.append(key_word)
# print('keywords acquired')

# detail = [url, title, publisher, doc_id, auths, keys, abstract]
# print(detail)
    
# file = './data/details.csv'
# insert_detail(file, detail)
# print()
# sleep(5)

# %%
df = pd.read_csv('./data/urls-copy.csv')
# Out:
# 0       https://www.mendeley.com/catalogue/189518ae-c7...
# 1       https://www.mendeley.com/catalogue/e3b6b38f-06...
# 2       https://www.mendeley.com/catalogue/f85f3983-fc...
# 3       https://www.mendeley.com/catalogue/c5045303-e1...
# 4       https://www.mendeley.com/catalogue/973c2f5a-03...
#                               ...
# 1894    https://www.mendeley.com/catalogue/95b402eb-be...
# 1895    https://www.mendeley.com/catalogue/5438be1d-31...
# 1896    https://www.mendeley.com/catalogue/a0d6580a-f8...
# 1897    https://www.mendeley.com/catalogue/2d3c8eb8-f3...
# 1898    https://www.mendeley.com/catalogue/0980df84-07...
# Name: url, Length: 1899, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1899 entries, 0 to 1898
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     1899 non-null   object
# dtypes: object(1)
# memory usage: 15.0+ KB

# %%
details = pd.read_csv('./data/details.csv', encoding='cp1252')
url_details = details['url'].tolist()
url_details
# Out:
# ['https://www.mendeley.com/catalogue/189518ae-c7f3-3950-b1a9-472e538777eb',
#  'https://www.mendeley.com/catalogue/e3b6b38f-0608-3cfb-8df6-b5bf94036104',
#  'https://www.mendeley.com/catalogue/f85f3983-fccd-3d8e-b167-86c2dcab1b37',
#  'https://www.mendeley.com/catalogue/c5045303-e187-3c49-8a56-c39d8301fd3f',
#  'https://www.mendeley.com/catalogue/973c2f5a-0324-37c4-8c1c-3721a2ff1a65',
#  'https://www.mendeley.com/catalogue/9225d55b-8562-3347-b3b5-21e532dbcf82',
#  'https://www.mendeley.com/catalogue/6bb03d56-9e54-3e2a-8b60-d02758aa7307',
#  'https://www.mendeley.com/catalogue/d83c4a2d-4657-3ad3-8696-0e28eaa03b19',
#  'https://www.mendeley.com/catalogue/bb78589e-3674-38ab-953e-abf94500b7d0',
#  'https://www.mendeley.com/catalogue/aa50dc72-4f08-3f0d-bfe1-88bc456274b6',
#  'https://www.mendeley.com/catalogue/3e0e04a8-ac1a-387e-acbd-c8c491c208a6',
#  'https://www.mendeley.com/catalogue/56b78b9c-83de-3138-9f67-dbc55e99981c',
#  'https://www.mendeley.com/catalogue/e9458951-f849-3b59-b9f3-f05a951ecf33',
#  'https://www.mendeley.com/catalogue/21bd19eb-026c-3243-bf48-20347be57790',
#  'https://www.mendeley.com/catalogue/36bee2a2-aaa0-3815-ac3d-784e45b9a91e',
#  'https://www.mendeley.com/catalogue/13dfcfaa-c8b5-35d2-b3aa-0c81b49116de',
#  'https://www.mendeley.com/catalogue/382e1da4-0772-3ec6-acce-ae272ac6a728',
#  'https://www.mendeley.com/catalogue/6cd12dd5-86ea-3ac7-808a-b9a58c849953',
#  'https://www.mendeley.com/catalogue/73aac1fd-5195-3b65-b872-306f5a4a7edf',
#  'https://www.mendeley.com/catalogue/5b4de61d-b5d5-347c-a868-576acf6f0d5a',
#  'https://www.mendeley.com/catalogue/73fc75ba-23fd-3807-a1b9-559a1a5904fa',
#  'https://www.mendeley.com/catalogue/89fb0564-8e45-3a4d-a3c8-0be6e6dff731',
#  'https://www.mendeley.com/catalogue/2b4fa36b-8706-3cf2-bf23-6e3067d0c060',
#  'https://www.mendeley.com/catalogue/0d7eb7d2-fda4-3e78-8c50-9c3b43f339f1',
#  'https://www.mendeley.com/catalogue/d9cf73e3-20b9-36ed-8fb3-83e92a3ef1b1',
#  'https://www.mendeley.com/catalogue/c70ed088-bdcc-3605-a00d-41ca440b0ed8',
#  'https://www.mendeley.com/catalogue/cbd98a19-a692-3cef-afd0-84ac701df528',
#  'https://www.mendeley.com/catalogue/ee2a011e-7817-31eb-9731-f9c200c5b581',
#  'https://www.mendeley.com/catalogue/7df9c350-f7f4-3947-bf9a-e7b9cf0e1e18',
#  'https://www.mendeley.com/catalogue/5bc79005-998f-3938-bc00-03388260f2ee',
#  'https://www.mendeley.com/catalogue/273475f0-82b2-3a2f-87d4-a64ff340b74a',
#  'https://www.mendeley.com/catalogue/18321559-7f0f-3319-85ac-7b168c882608',
#  'https://www.mendeley.com/catalogue/70d0deab-e756-301c-ad36-2b7e94ba6c1d',
#  'https://www.mendeley.com/catalogue/fef77267-5888-3dbe-9077-0cc5e325651c',
#  'https://www.mendeley.com/catalogue/e77894f8-cbfb-3a43-bf92-c7f7d8b5b8c8',
#  'https://www.mendeley.com/catalogue/cacace7b-1c04-3278-8bb3-63ce3c5dfbb6',
#  'https://www.mendeley.com/catalogue/845e7739-e45f-34f4-a9c3-568f17ed9332',
#  'https://www.mendeley.com/catalogue/b3bb3f09-4c59-3099-9f15-49fc9cf919a4',
#  'https://www.mendeley.com/catalogue/eb7bfb01-00d3-3720-9d3c-4fbb746fcf1f',
#  'https://www.mendeley.com/catalogue/1583e0b7-cdc8-30af-8d81-c444618726a7',
#  'https://www.mendeley.com/catalogue/a4d43296-bf7f-35be-9a4f-7db42c873be4',
#  'https://www.mendeley.com/catalogue/53004799-46dd-355e-b867-609a413f389f',
#  'https://www.mendeley.com/catalogue/a48d0a66-7c57-3c67-ba4b-7b5ed0995580',
#  'https://www.mendeley.com/catalogue/677184a3-6d13-3a39-bec2-c62540364640',
#  'https://www.mendeley.com/catalogue/b4f21d06-d4dd-3eb0-909c-001728617e0e',
#  'https://www.mendeley.com/catalogue/4d0421c8-6bbe-35f7-b8ca-0287bc91f64a',
#  'https://www.mendeley.com/catalogue/99dc8523-7126-3796-86b3-b3c871bd1c4a',
#  'https://www.mendeley.com/catalogue/5580c171-4e29-3f4c-b0ac-1d8dd5a7c8cc']

# %%
def check_data(url, details):
    if url in details:
        print('url in index %s is already inserted'%(details.index(url)))
    else:
        details.append(url)
        print('link on index %s has been inserted'%(details.index(url)))

# %%
for i in range(len(urls)):
#     check_data(urls[i], url_details)
    if urls[i] in url_details:
        print('url in index %s is already inserted'%(i))
    else:
        url_details.append(urls[i])
        print('link on index %s has been inserted'%(i))
# Out:
# url in index 0 is already inserted
# url in index 1 is already inserted
# url in index 2 is already inserted
# url in index 3 is already inserted
# url in index 4 is already inserted
# url in index 5 is already inserted
# url in index 6 is already inserted
# url in index 7 is already inserted
# url in index 8 is already inserted
# url in index 9 is already inserted
# url in index 10 is already inserted
# url in index 11 is already inserted
# url in index 12 is already inserted
# url in index 13 is already inserted
# url in index 14 is already inserted
# url in index 15 is already inserted
# url in index 16 is already inserted
# url in index 17 is already inserted
# url in index 18 is already inserted
# url in index 19 is already inserted
# url in index 20 is already inserted
# url in index 21 is already inserted
# url in index 22 is already inserted
# url in index 23 is already inserted
# url in index 24 is already inserted
# url in index 25 is already inserted
# url in index 26 is already inserted
# url in index 27 is already inserted
# url in index 28 is already inserted
# url in index 29 is already inserted
# url in index 30 is already inserted
# url in index 31 is already inserted
# url in index 32 is already inserted
# url in index 33 is already inserted
# url in index 34 is already inserted
# url in index 35 is already inserted
# url in index 36 is already inserted
# url in index 37 is already inserted
# url in index 38 is already inserted
# url in index 39 is already inserted
# url in index 40 is already inserted
# url in index 41 is already inserted
# url in index 42 is already inserted
# url in index 43 is already inserted
# url in index 44 is already inserted
# url in index 45 is already inserted
# url in index 46 is already inserted
# url in index 47 is already inserted
# url in index 48 is already inserted
# url in index 49 is already inserted
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 50
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-7c605984348a> in <module>
#       1 for i in range(len(urls)):
#       2 #     check_data(urls[i], url_details)
# ----> 3     if urls[i] in url_details:
#       4         print('url in index %s is already inserted'%(i))
#       5     else:
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 50

# %%
df = df.drop_duplicates(keep='first', inplace=True)
df.info()
# type(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-bf4714a54f4e> in <module>
#       1 df = df.drop_duplicates(keep='first', inplace=True)
# ----> 2 df.info()
#       3 # type(df)
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
duplicatedRows = df[~df.duplicated()]
duplicatedRows
# Out:
#                                                     url
# 0     https://www.mendeley.com/catalogue/189518ae-c7...
# 1     https://www.mendeley.com/catalogue/e3b6b38f-06...
# 2     https://www.mendeley.com/catalogue/f85f3983-fc...
# 3     https://www.mendeley.com/catalogue/c5045303-e1...
# 4     https://www.mendeley.com/catalogue/973c2f5a-03...
# ...                                                 ...
# 1894  https://www.mendeley.com/catalogue/95b402eb-be...
# 1895  https://www.mendeley.com/catalogue/5438be1d-31...
# 1896  https://www.mendeley.com/catalogue/a0d6580a-f8...
# 1897  https://www.mendeley.com/catalogue/2d3c8eb8-f3...
# 1898  https://www.mendeley.com/catalogue/0980df84-07...
#
# [1818 rows x 1 columns]

# %%
duplicatedRows.info()
duplicatedRows.to_csv('./data/urls.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1818 entries, 0 to 1898
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     1818 non-null   object
# dtypes: object(1)
# memory usage: 28.4+ KB

# %%
df = duplicatedRows
urls = df['url']
urls
# Out:
# 0       https://www.mendeley.com/catalogue/189518ae-c7...
# 1       https://www.mendeley.com/catalogue/e3b6b38f-06...
# 2       https://www.mendeley.com/catalogue/f85f3983-fc...
# 3       https://www.mendeley.com/catalogue/c5045303-e1...
# 4       https://www.mendeley.com/catalogue/973c2f5a-03...
#                               ...
# 1894    https://www.mendeley.com/catalogue/95b402eb-be...
# 1895    https://www.mendeley.com/catalogue/5438be1d-31...
# 1896    https://www.mendeley.com/catalogue/a0d6580a-f8...
# 1897    https://www.mendeley.com/catalogue/2d3c8eb8-f3...
# 1898    https://www.mendeley.com/catalogue/0980df84-07...
# Name: url, Length: 1818, dtype: object

# %%
import pandas as pd
import csv

# %%
urls = pd.read_csv('./data/urls-copy.csv')
detail_urls = pd.read_csv('./data/details.csv', usecols=['url'])

# %%
print(urls.info())
print()
print(detail_urls.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1818 entries, 0 to 1817
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     1818 non-null   object
# dtypes: object(1)
# memory usage: 14.3+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1219 entries, 0 to 1218
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     1219 non-null   object
# dtypes: object(1)
# memory usage: 9.6+ KB
# None

# %%
urls['url'][1218]
# Out:
# 'https://www.mendeley.com/catalogue/267d9a92-6731-3940-907e-dcce06f91209'

# %%
for i in range(len(detail_urls)):
    detail_urls['url'][i] = urls['url'][i]

print(detail_urls)
# Out:
#                                                     url
# 0     https://www.mendeley.com/catalogue/189518ae-c7...
# 1     https://www.mendeley.com/catalogue/e3b6b38f-06...
# 2     https://www.mendeley.com/catalogue/f85f3983-fc...
# 3     https://www.mendeley.com/catalogue/c5045303-e1...
# 4     https://www.mendeley.com/catalogue/973c2f5a-03...
# ...                                                 ...
# 1214  https://www.mendeley.com/catalogue/9d632ffa-8f...
# 1215  https://www.mendeley.com/catalogue/5cbbc3c9-6d...
# 1216  https://www.mendeley.com/catalogue/ec74713b-58...
# 1217  https://www.mendeley.com/catalogue/25027bc0-89...
# 1218  https://www.mendeley.com/catalogue/267d9a92-67...
#
# [1219 rows x 1 columns]

# %%
detail_urls = detail_urls['url'].tolist()
detail_urls
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-ef6f29af0c60> in <module>
# ----> 1 detail_urls = detail_urls['url'].tolist()
#       2 detail_urls
#
# TypeError: list indices must be integers or slices, not str

# %%
old = pd.read_csv('./data/details.csv')
old = old.drop(['url'], axis=1)
old
# Out:
#                                                   title  \
# 0     Effect of supply chain cultural competence on ...
# 1     Effect of supply chain technology internalizat...
# 2     A model to evaluate supply chain technology im...
# 3     Exploring the role of TQM and supply chain pra...
# 4     Determinant Factors of Supply Chain Technology...
# ...                                                 ...
# 1214  Investigating the impact of inventory inaccura...
# 1215  Critical Review of Procurement Method Research...
# 1216  Examining RFID applications in supply chain ma...
# 1217  Consumer trust in the food value chain and its...
# 1218  Impact of supply chain management practices on...
#
#                                               publisher  \
# 0     International Journal of Supply Chain Manageme...
# 1     Business Process Management Journal (2019) 26(...
# 2                        Transport (2018) 33(3) 779-792
# 3     Uncertain Supply Chain Management (2016) 7(2) ...
# 4     Malaysian Journal of Business and Economics (2...
# ...                                                 ...
# 1214  Journal of Modelling in Management (2019) 14(2...
# 1215      Procedia Economics and Finance (2015) 21 6-13
# 1216      Communications of the ACM (2007) 50(7) 92-101
# 1217                              Food Policy (2020) 92
# 1218  AFRICAN JOURNAL OF BUSINESS MANAGEMENT (2012) ...
#
#                              doc_id  \
# 0                          20507399
# 1         10.1108/BPMJ-04-2019-0150
# 2       10.3846/transport.2018.5468
# 3         10.5267/j.uscm.2018.9.001
# 4                               NaN
# ...                             ...
# 1214       10.1108/JM2-08-2017-0081
# 1215  10.1016/s2212-5671(15)00144-6
# 1216        10.1145/1272516.1272520
# 1217  10.1016/j.foodpol.2020.101880
# 1218            10.5897/ajbm11.1136
#
#                                                 authors  \
# 0                                      ['Mekhum W', '']
# 1                   ['Pattanayak D', 'Punyatoya P', '']
# 2      ['Soltany Z', 'Rostamzadeh R', 'Skrickij V', '']
# 3     ['Basheer M', 'Siam M', 'Awn A', 'et al.See mo...
# 4                           ['Faisal S', 'Idris S', '']
# ...                                                 ...
# 1214                     ['Drakaki M', 'Tzionas P', '']
# 1215                          ['Naoum S', 'Egbu C', '']
# 1216  ['Niederman F', 'Mathieu R', 'Morley R', 'et a...
# 1217  ['Macready A', 'Hieke S', 'Klimczuk-Kochańska ...
# 1218                          ['Davood Gharakhani', '']
#
#                                                keywords  \
# 0     ['Performance', 'SMEs', 'Supply chain cultural...
# 1     ['Construction industry', 'E-procurement', 'Su...
# 2     ['IT enabled', 'Organizational performance', '...
# 3     ['Firm supply performance', 'Information techn...
# 4     ['adoption', 'diffusion of innovation', 'suppl...
# ...                                                 ...
# 1214  ['Bullwhip effect', 'Inventory inaccuracy', 'M...
# 1215                                                 []
# 1216                                                 []
# 1217                           ['', '', '', '', '', '']
# 1218                                                 []
#
#                                                abstract
# 0     Performance is a key indicator for the surviva...
# 1     Purpose: The purpose of this paper is to exami...
# 2     Supply Chain Management (SCM) aims to achieve ...
# 3     The primary objective of this paper is to inve...
# 4     Small and Medium Enterprises (SMEs) are the ke...
# ...                                                 ...
# 1214  Purpose: Information distortion results in dem...
# 1215  One of the features of the construction indust...
# 1216  Technology infrastructure, business process, a...
# 1217  In order to measure consumer trust in food cha...
# 1218  Supply chain management (SCM) is effective way...
#
# [1219 rows x 6 columns]

# %%
old
# Out:
#                                                   title  \
# 0     Effect of supply chain cultural competence on ...
# 1     Effect of supply chain technology internalizat...
# 2     A model to evaluate supply chain technology im...
# 3     Exploring the role of TQM and supply chain pra...
# 4     Determinant Factors of Supply Chain Technology...
# ...                                                 ...
# 1214  Investigating the impact of inventory inaccura...
# 1215  Critical Review of Procurement Method Research...
# 1216  Examining RFID applications in supply chain ma...
# 1217  Consumer trust in the food value chain and its...
# 1218  Impact of supply chain management practices on...
#
#                                               publisher  \
# 0     International Journal of Supply Chain Manageme...
# 1     Business Process Management Journal (2019) 26(...
# 2                        Transport (2018) 33(3) 779-792
# 3     Uncertain Supply Chain Management (2016) 7(2) ...
# 4     Malaysian Journal of Business and Economics (2...
# ...                                                 ...
# 1214  Journal of Modelling in Management (2019) 14(2...
# 1215      Procedia Economics and Finance (2015) 21 6-13
# 1216      Communications of the ACM (2007) 50(7) 92-101
# 1217                              Food Policy (2020) 92
# 1218  AFRICAN JOURNAL OF BUSINESS MANAGEMENT (2012) ...
#
#                              doc_id  \
# 0                          20507399
# 1         10.1108/BPMJ-04-2019-0150
# 2       10.3846/transport.2018.5468
# 3         10.5267/j.uscm.2018.9.001
# 4                               NaN
# ...                             ...
# 1214       10.1108/JM2-08-2017-0081
# 1215  10.1016/s2212-5671(15)00144-6
# 1216        10.1145/1272516.1272520
# 1217  10.1016/j.foodpol.2020.101880
# 1218            10.5897/ajbm11.1136
#
#                                                 authors  \
# 0                                      ['Mekhum W', '']
# 1                   ['Pattanayak D', 'Punyatoya P', '']
# 2      ['Soltany Z', 'Rostamzadeh R', 'Skrickij V', '']
# 3     ['Basheer M', 'Siam M', 'Awn A', 'et al.See mo...
# 4                           ['Faisal S', 'Idris S', '']
# ...                                                 ...
# 1214                     ['Drakaki M', 'Tzionas P', '']
# 1215                          ['Naoum S', 'Egbu C', '']
# 1216  ['Niederman F', 'Mathieu R', 'Morley R', 'et a...
# 1217  ['Macready A', 'Hieke S', 'Klimczuk-Kochańska ...
# 1218                          ['Davood Gharakhani', '']
#
#                                                keywords  \
# 0     ['Performance', 'SMEs', 'Supply chain cultural...
# 1     ['Construction industry', 'E-procurement', 'Su...
# 2     ['IT enabled', 'Organizational performance', '...
# 3     ['Firm supply performance', 'Information techn...
# 4     ['adoption', 'diffusion of innovation', 'suppl...
# ...                                                 ...
# 1214  ['Bullwhip effect', 'Inventory inaccuracy', 'M...
# 1215                                                 []
# 1216                                                 []
# 1217                           ['', '', '', '', '', '']
# 1218                                                 []
#
#                                                abstract
# 0     Performance is a key indicator for the surviva...
# 1     Purpose: The purpose of this paper is to exami...
# 2     Supply Chain Management (SCM) aims to achieve ...
# 3     The primary objective of this paper is to inve...
# 4     Small and Medium Enterprises (SMEs) are the ke...
# ...                                                 ...
# 1214  Purpose: Information distortion results in dem...
# 1215  One of the features of the construction indust...
# 1216  Technology infrastructure, business process, a...
# 1217  In order to measure consumer trust in food cha...
# 1218  Supply chain management (SCM) is effective way...
#
# [1219 rows x 6 columns]

# %%
new = old.insert(loc=0, column='url', value=detail_urls)
new
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-dd3f82ec7ed4> in <module>
# ----> 1 new = old.insert(loc=0, column='url', value=detail_urls)
#       2 new
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3626         self._ensure_valid_index(value)
#    3627         value = self._sanitize_column(column, value, broadcast=False)
# -> 3628         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3629
#    3630     def assign(self, **kwargs) -> "DataFrame":
#
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
#    1176             # Should this be a different kind of error??
# -> 1177             raise ValueError(f"cannot insert {item}, already exists")
#    1178
#    1179         if not isinstance(loc, int):
#
# ValueError: cannot insert url, already exists

# %%
old
# Out:
#                                                     url  \
# 0     https://www.mendeley.com/catalogue/189518ae-c7...
# 1     https://www.mendeley.com/catalogue/e3b6b38f-06...
# 2     https://www.mendeley.com/catalogue/f85f3983-fc...
# 3     https://www.mendeley.com/catalogue/c5045303-e1...
# 4     https://www.mendeley.com/catalogue/973c2f5a-03...
# ...                                                 ...
# 1214  https://www.mendeley.com/catalogue/9d632ffa-8f...
# 1215  https://www.mendeley.com/catalogue/5cbbc3c9-6d...
# 1216  https://www.mendeley.com/catalogue/ec74713b-58...
# 1217  https://www.mendeley.com/catalogue/25027bc0-89...
# 1218  https://www.mendeley.com/catalogue/267d9a92-67...
#
#                                                   title  \
# 0     Effect of supply chain cultural competence on ...
# 1     Effect of supply chain technology internalizat...
# 2     A model to evaluate supply chain technology im...
# 3     Exploring the role of TQM and supply chain pra...
# 4     Determinant Factors of Supply Chain Technology...
# ...                                                 ...
# 1214  Investigating the impact of inventory inaccura...
# 1215  Critical Review of Procurement Method Research...
# 1216  Examining RFID applications in supply chain ma...
# 1217  Consumer trust in the food value chain and its...
# 1218  Impact of supply chain management practices on...
#
#                                               publisher  \
# 0     International Journal of Supply Chain Manageme...
# 1     Business Process Management Journal (2019) 26(...
# 2                        Transport (2018) 33(3) 779-792
# 3     Uncertain Supply Chain Management (2016) 7(2) ...
# 4     Malaysian Journal of Business and Economics (2...
# ...                                                 ...
# 1214  Journal of Modelling in Management (2019) 14(2...
# 1215      Procedia Economics and Finance (2015) 21 6-13
# 1216      Communications of the ACM (2007) 50(7) 92-101
# 1217                              Food Policy (2020) 92
# 1218  AFRICAN JOURNAL OF BUSINESS MANAGEMENT (2012) ...
#
#                              doc_id  \
# 0                          20507399
# 1         10.1108/BPMJ-04-2019-0150
# 2       10.3846/transport.2018.5468
# 3         10.5267/j.uscm.2018.9.001
# 4                               NaN
# ...                             ...
# 1214       10.1108/JM2-08-2017-0081
# 1215  10.1016/s2212-5671(15)00144-6
# 1216        10.1145/1272516.1272520
# 1217  10.1016/j.foodpol.2020.101880
# 1218            10.5897/ajbm11.1136
#
#                                                 authors  \
# 0                                      ['Mekhum W', '']
# 1                   ['Pattanayak D', 'Punyatoya P', '']
# 2      ['Soltany Z', 'Rostamzadeh R', 'Skrickij V', '']
# 3     ['Basheer M', 'Siam M', 'Awn A', 'et al.See mo...
# 4                           ['Faisal S', 'Idris S', '']
# ...                                                 ...
# 1214                     ['Drakaki M', 'Tzionas P', '']
# 1215                          ['Naoum S', 'Egbu C', '']
# 1216  ['Niederman F', 'Mathieu R', 'Morley R', 'et a...
# 1217  ['Macready A', 'Hieke S', 'Klimczuk-Kochańska ...
# 1218                          ['Davood Gharakhani', '']
#
#                                                keywords  \
# 0     ['Performance', 'SMEs', 'Supply chain cultural...
# 1     ['Construction industry', 'E-procurement', 'Su...
# 2     ['IT enabled', 'Organizational performance', '...
# 3     ['Firm supply performance', 'Information techn...
# 4     ['adoption', 'diffusion of innovation', 'suppl...
# ...                                                 ...
# 1214  ['Bullwhip effect', 'Inventory inaccuracy', 'M...
# 1215                                                 []
# 1216                                                 []
# 1217                           ['', '', '', '', '', '']
# 1218                                                 []
#
#                                                abstract
# 0     Performance is a key indicator for the surviva...
# 1     Purpose: The purpose of this paper is to exami...
# 2     Supply Chain Management (SCM) aims to achieve ...
# 3     The primary objective of this paper is to inve...
# 4     Small and Medium Enterprises (SMEs) are the ke...
# ...                                                 ...
# 1214  Purpose: Information distortion results in dem...
# 1215  One of the features of the construction indust...
# 1216  Technology infrastructure, business process, a...
# 1217  In order to measure consumer trust in food cha...
# 1218  Supply chain management (SCM) is effective way...
#
# [1219 rows x 7 columns]

# %%
import pandas as pd

# %%
cols = ['url','title', 'publihser', 'doc_id', 'authors', 'keywords', 'abstract']
df = pd.read_csv('D:/supply_chain_technology_details.csv', usecols=cols)
df
# Out:
#                                                     url  \
# 0     https://www.mendeley.com/catalogue/cb30a1d6-4e...
# 1     https://www.mendeley.com/catalogue/31947e74-7d...
# 2     https://www.mendeley.com/catalogue/189518ae-c7...
# 3     https://www.mendeley.com/catalogue/e3b6b38f-06...
# 4     https://www.mendeley.com/catalogue/f85f3983-fc...
# ...                                                 ...
# 1843  https://www.mendeley.com/catalogue/95b402eb-be...
# 1844  https://www.mendeley.com/catalogue/5438be1d-31...
# 1845  https://www.mendeley.com/catalogue/a0d6580a-f8...
# 1846  https://www.mendeley.com/catalogue/2d3c8eb8-f3...
# 1847  https://www.mendeley.com/catalogue/0980df84-07...
#
#                                                   title  \
# 0     The rise of blockchain technology in agricultu...
# 1     Transforming agriculture supply chain with tec...
# 2     Effect of supply chain cultural competence on ...
# 3     Effect of supply chain technology internalizat...
# 4     A model to evaluate supply chain technology im...
# ...                                                 ...
# 1843  Current issues and challenges of supply chain ...
# 1844  Mobile supply chain management: Challenges for...
# 1845  Effect of strategic alliance based on port cha...
# 1846  Risk categories in halal food transportation: ...
# 1847  The Relationship between Supply Chain Manageme...
#
#                                               publihser  \
# 0                 Trends in Food Science and Technology
# 1     Proceedings of the International Conference on...
# 2     International Journal of Supply Chain Manageme...
# 3     Business Process Management Journal (2019) 26(...
# 4                        Transport (2018) 33(3) 779-792
# ...                                                 ...
# 1843      Ekonomska Istrazivanja (2012) 25(4) 1101-1112
# 1844                Technovation (2006) 26(5-6) 682-686
# 1845    Cogent Business and Management (2019) 6(1) 1-14
# 1846  International Journal of Supply Chain Manageme...
# 1847  Journal of Arts & Social Sciences (2019) 2(2) ...
#
#                                   doc_id  \
# 0             10.1016/j.tifs.2019.07.034
# 1                               21698767
# 2                               20507399
# 3              10.1108/BPMJ-04-2019-0150
# 4            10.3846/transport.2018.5468
# ...                                  ...
# 1843      10.1080/1331677x.2012.11517551
# 1844  10.1016/j.technovation.2005.07.003
# 1845       10.1080/23311975.2019.1567893
# 1846                            20507399
# 1847                                 NaN
#
#                                                 authors  \
# 0      ["Kamilaris A","Fonts A","Prenafeta-Boldύ F",""]
# 1     ["Karunanayaka C","Vidanagamachchi K","Wickram...
# 2                                       ["Mekhum W",""]
# 3                     ["Pattanayak D","Punyatoya P",""]
# 4         ["Soltany Z","Rostamzadeh R","Skrickij V",""]
# ...                                                 ...
# 1843                        ["Croznik A","Trkman P",""]
# 1844                                       ["Eng T",""]
# 1845            ["Sirajuddin","Zagloel T","Sunaryo",""]
# 1846              ["Yaacob T","Rahman F","Jaafar H",""]
# 1847                                 ["Manokaran R",""]
#
#                                                keywords  \
# 0     ["Barriers","Benefits","Blockchain technology"...
# 1     ["Agriculture supply chain","Digital transform...
# 2     ["Performance","SMEs","Supply chain cultural c...
# 3     ["Construction industry","E-procurement","Supp...
# 4     ["IT enabled","Organizational performance","Si...
# ...                                                 ...
# 1843  ["Business redesign","Information technology r...
# 1844  ["Coordination","Implementation","Integration"...
# 1845  ["port alliance","port performance","port stra...
# 1846  ["Contamination risk","Halal food","Halal food...
# 1847  ["customer satisfaction","information","inform...
#
#                                                abstract
# 0     Blockchain is an emerging digital technology a...
# 1     With the increase in the global population, na...
# 2     Performance is a key indicator for the surviva...
# 3     Purpose: The purpose of this paper is to exami...
# 4     Supply Chain Management (SCM) aims to achieve ...
# ...                                                 ...
# 1843  Efficient supply chain management is crucial f...
# 1844  Mobile supply chain management (mSCM) is fast ...
# 1845  This study investigates the effect of integrat...
# 1846  The issue of halal food has attracted public a...
# 1847  The main purpose of this study is to understan...
#
# [1848 rows x 7 columns]
